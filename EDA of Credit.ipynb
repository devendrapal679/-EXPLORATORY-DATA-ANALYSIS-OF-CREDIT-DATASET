# %%
import pandas as pd
A = pd.read_csv("C:/Users/tpasv/Desktop/Data Science/Data Science/Dataset/Credit.csv")

# %%
A.head(5)
# Out:
#    Unnamed: 0  ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           1   1   14.891   3606     283      2   34         11    Male
# 1           2   2  106.025   6645     483      3   82         15  Female
# 2           3   3  104.593   7075     514      4   71         11    Male
# 3           4   4  148.924   9504     681      3   36         11  Female
# 4           5   5   55.882   4897     357      2   68         16    Male
#
#   Student Married  Ethnicity  Balance
# 0      No     Yes  Caucasian      333
# 1     Yes     Yes      Asian      903
# 2      No      No      Asian      580
# 3      No      No      Asian      964
# 4      No     Yes  Caucasian      331

# %% [markdown]
# # Univariate for Continuous Data

# %%
import seaborn as sb

# %%
sb.distplot(A.Income)
# Out:
# G:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %%
sb.distplot(A['Limit'])
# Out:
# G:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Limit', ylabel='Density'>

# %%
A.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
A.corr()
# Out:
#             Unnamed: 0        ID    Income     Limit    Rating     Cards  \
# Unnamed: 0    1.000000  1.000000  0.037203  0.024172  0.021985 -0.036304
# ID            1.000000  1.000000  0.037203  0.024172  0.021985 -0.036304
# Income        0.037203  0.037203  1.000000  0.792088  0.791378 -0.018273
# Limit         0.024172  0.024172  0.792088  1.000000  0.996880  0.010231
# Rating        0.021985  0.021985  0.791378  0.996880  1.000000  0.053239
# Cards        -0.036304 -0.036304 -0.018273  0.010231  0.053239  1.000000
# Age           0.058603  0.058603  0.175338  0.100888  0.103165  0.042948
# Education    -0.001415 -0.001415 -0.027692 -0.023549 -0.030136 -0.051084
# Balance       0.006064  0.006064  0.463656  0.861697  0.863625  0.086456
#
#                  Age  Education   Balance
# Unnamed: 0  0.058603  -0.001415  0.006064
# ID          0.058603  -0.001415  0.006064
# Income      0.175338  -0.027692  0.463656
# Limit       0.100888  -0.023549  0.861697
# ...

# %% [markdown]
# # Univariate for categorical data

# %%
A.Gender.value_counts()
# Out:
# Female    207
#  Male     193
# Name: Gender, dtype: int64

# %%
A.Gender.value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
A.Student.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sb.countplot(A.Ethnicity)
# Out:
# G:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
A.Married.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Married'>

# %% [markdown]
# # Bivariate(con vs con)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(A.Income,A.Limit)

# %%
plt.scatter(A.Rating,A.Balance,c="red",marker="+")

# %%
plt.scatter(A.Income,A.Limit,c="green",marker="+",alpha=0.5)
plt.xlabel("Income of person")
plt.ylabel("Limit of credit")
plt.title("Scatterplot of Income vs Limit")
# Out:
# Text(0.5, 1.0, 'Scatterplot of Income vs Limit')

# %% [markdown]
# # Bivariate(cat vs con)

# %%
sb.boxplot(A.Gender,A.Income)
# Out:
# G:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='Income'>

# %%
sb.boxplot(A.Ethnicity,A.Income)
# Out:
# G:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='Income'>

# %% [markdown]
# # Bivariate(cat vs cat)

# %%
pd.crosstab(A.Ethnicity,A.Married)
# Out:
# Married           No  Yes
# Ethnicity
# African American  47   52
# Asian             32   70
# Caucasian         76  123

# %%
sb.countplot(A.Ethnicity,hue=A.Student)
# Out:
# G:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %% [markdown]
# # Multivariate

# %%
sb.scatterplot(A.Income,A.Limit,hue=A.Ethnicity)
# Out:
# G:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income', ylabel='Limit'>

# %%
sb.heatmap(A.corr())
# Out:
# <AxesSubplot:>

# %%
sb.pairplot(A)
